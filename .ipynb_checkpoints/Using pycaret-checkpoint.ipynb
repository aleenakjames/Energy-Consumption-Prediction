# %%
from pycaret.regression import *
import pandas as pd
df = pd.read_csv("HomeC.csv")
df = df.drop(df.columns[23], axis=1)
df = df.dropna()
df['time'] = df['time'].astype(float)
numeric_cols = df.select_dtypes(include=['int', 'float']).columns
df = df.drop(columns=df.columns.difference(numeric_cols))
df = df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from pycaret.regression import *
#       2 import pandas as pd
#       3 df = pd.read_csv("HomeC.csv")
#
# File ~\.eclipse\anaconda\lib\site-packages\pycaret\regression\__init__.py:1, in <module>
# ----> 1 from pycaret.regression.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     check_drift,
#       6     check_fairness,
#       7     compare_models,
#       8     convert_model,
#       9     create_api,
#      10     create_app,
#      11     create_docker,
#      12     create_model,
#      13     dashboard,
#      14     deep_check,
#      15     deploy_model,
#      16     eda,
#      17     ensemble_model,
#      18     evaluate_model,
#      19     finalize_model,
#      20     get_allowed_engines,
# ...

# %%
x = df.iloc[:, 1]
x = x.values.reshape(-1, 1)
y = df.iloc[:, [col for col in range(len(df.columns)) if col != 1]]

# %%
exp = setup(data=df, target='use [kW]', session_id=42)
# Out:
# <style type="text/css">
# #T_c07dd_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c07dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c07dd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c07dd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c07dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c07dd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c07dd_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_c07dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c07dd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c07dd_row1_col1" class="data row1 col1" >use [kW]</td>
#     </tr>
#     <tr>
#       <th id="T_c07dd_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               23:28:24
# Status     . . . . . . . . . . . . . . . . . .       Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Regressor
# <style type="text/css">
# #T_6eed5 th {
#   text-align: left;
# }
# ...

# %%
lr = create_model('lr')

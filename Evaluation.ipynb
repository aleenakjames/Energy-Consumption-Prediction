# %%
import pandas as pd
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from pycaret.regression import *
#
# File ~\.eclipse\anaconda\lib\site-packages\pycaret\regression\__init__.py:1, in <module>
# ----> 1 from pycaret.regression.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     check_drift,
#       6     check_fairness,
#       7     compare_models,
#       8     convert_model,
#       9     create_api,
#      10     create_app,
#      11     create_docker,
#      12     create_model,
#      13     dashboard,
#      14     deep_check,
#      15     deploy_model,
#      16     eda,
#      17     ensemble_model,
#      18     evaluate_model,
#      19     finalize_model,
#      20     get_allowed_engines,
#      21     get_config,
#      22     get_current_experiment,
# ...

# %%
dg = pd.read_csv("new1.csv")
dg = dg.head(30)
x = dg.iloc[:, 0]
x = x.values.reshape(-1, 1)
y = dg.iloc[:, [col for col in range(len(dg.columns)) if col != 0]]
exp = setup(data=dg, target='use [kW]')
# Out:
# <style type="text/css">
# #T_aee56_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_aee56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aee56_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_aee56_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aee56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aee56_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_aee56_row0_col1" class="data row0 col1" >260</td>
#     </tr>
#     <tr>
#       <th id="T_aee56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aee56_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_aee56_row1_col1" class="data row1 col1" >use [kW]</td>
#     </tr>
#     <tr>
#       <th id="T_aee56_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_890b9_row10_col0, #T_890b9_row10_col1, #T_890b9_row10_col2, #T_890b9_row10_col3, #T_890b9_row10_col4, #T_890b9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_890b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_890b9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_890b9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_890b9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_890b9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_890b9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_890b9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(lr, plot='error', fold=0)

# %%
plot_model(lr, plot='residuals', fold=9)

# %%
plot_model(lr, plot='parameter', fold = 9)
# Out:
#                Parameters
# copy_X               True
# fit_intercept        True
# n_jobs                 -1
# normalize      deprecated
# positive            False

# %%
plot_model(lr, plot='cooks',fold = 0)

# %%
plot_model(lr, plot='rfe')

# %%
plot_model(lr, plot='feature')
